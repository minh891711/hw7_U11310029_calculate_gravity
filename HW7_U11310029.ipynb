# %%
import numpy as np

# %%
lon = 12.1878; lat = 48.1195; ele = 487.9; G0 = 980717.39

# %%
Ge = 978031.85;

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# 180 = np.pi
# 1 = np.pi / 180.0
fac = np.pi / 180.0  #度轉徑度

# %%
print(np.sin(90*fac))
# Out:
# 1.0

# %%
 #a-1
Gt = Ge*(1+0.005278895*np.sin(lat*fac)**2+0.000023462*np.sin(lat*fac)**4)
print(f"theoretical gravity : {Gt}")
# Out:
# theoretical gravity : 980900.9082144853

# %%
#a-2
FAC = ele*(0.308) 
print(f"FAC : {FAC} ")
# Out:
# FAC : 150.2732

# %%
#a-3
BC = ele*(0.112)
print(f"BC : {BC}")
# Out:
# BC : 54.6448

# %%
#a-4
Gfa = (G0 + FAC) - Gt
print(f"Gfa : {Gfa}")
# Out:
# Gfa : -33.24501448520459

# %%
#a-5
Gb = Gfa - BC
print(f"Gb : {Gb}")
# Out:
# Gb : -87.8898144852046

# %%
#b
gfa = G0 - Gt
print(f"gfa : {gfa}")

bc = ele*(-0.0687) 
print(f"bc : {bc}")

gb = gfa - bc
print(f"gb : {gb}")
# Out:
# gfa : -183.5182144852588
# bc : -33.51873
# gb : -149.9994844852588
